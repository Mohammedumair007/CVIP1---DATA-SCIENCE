# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your climate data into a DataFrame (replace 'your_data.csv' with your actual data file)
climate_data = pd.read_csv('/content/drive/MyDrive/CC ds/Climate.csv.csv')

# %%
# Display the first few rows of the dataset to understand its structure
print("First few rows of the dataset:")
print(climate_data.head())
# Out:
# First few rows of the dataset:
#          time  tavg  tmin  tmax  prcp
# 0  01-01-1990  22.9  19.1  28.4   NaN
# 1  02-01-1990  21.7   NaN  26.5   0.0
# 2  03-01-1990  21.0  16.4  26.5   0.0
# 3  04-01-1990  20.8   NaN  27.4   0.0
# 4  05-01-1990  20.4  14.2  26.1   0.0

# %%
# Check for missing values in the dataset
print("\nMissing values in the dataset:")
print(climate_data.isnull().sum())
# Out:
# Missing values in the dataset:
# time       0
# tavg      70
# tmin    1389
# tmax     629
# prcp    4620
# dtype: int64

# %%
# Handling missing values (you can customize this based on your data)
climate_data = climate_data.dropna()

# %%
# Basic statistics of the numerical columns
print("\nBasic statistics of the numerical columns:")
print(climate_data.describe())
# Out:
# Basic statistics of the numerical columns:
#               tavg         tmin         tmax         prcp
# count  6083.000000  6083.000000  6083.000000  6083.000000
# mean     23.755893    19.592750    29.525810     4.659642
# std       2.145914     2.109875     2.868972    12.896505
# min      17.500000     9.300000    19.800000     0.000000
# 25%      22.400000    18.900000    27.600000     0.000000
# 50%      23.400000    20.000000    29.100000     0.000000
# 75%      24.900000    20.700000    31.300000     2.750000
# max      32.400000    27.900000    38.500000   255.000000

# %%
# Visualize maximum temperature trends over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='time', y='tmax', data=climate_data, marker='o', color='b')
plt.title('Maximum Temperature Trends Over Time')
plt.xlabel('Year')
plt.ylabel('Maximum Temperature (°C)')
plt.grid(True)
plt.show()

# %%
# Visualize minimum temperature trends over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='time', y='tmin', data=climate_data, marker='o', color='r')
plt.title('Minimum Temperature Trends Over Time')
plt.xlabel('Year')
plt.ylabel('Minimum Temperature (°C)')
plt.grid(True)
plt.show()

# %%
# Visualize precipitation trends over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='time', y='prcp', data=climate_data, marker='o', color='g')
plt.title('Precipitation Trends Over Time')
plt.xlabel('Time')
plt.ylabel('Precipitation (mm)')
plt.grid(True)
plt.show()

# %%
# Explore correlations between variables
correlation_matrix = climate_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
